# %%
import numpy as np
import pandas as pd
import random
import requests
from citipy import citipy
from datetime import datetime

# %%
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | avera
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | homer
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | asau
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | konevo
# Processing Record 14 of Set 1 | eunice
# Processing Record 15 of Set 1 | bandar-e lengeh
# Processing Record 16 of Set 1 | kaitangata
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | penzance
# Processing Record 20 of Set 1 | itaituba
# Processing Record 21 of Set 1 | lahaina
# Processing Record 22 of Set 1 | moctezuma
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | sao felix do xingu
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | la sarre
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | matara
# Processing Record 32 of Set 1 | qasigiannguit
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | meulaboh
# Processing Record 36 of Set 1 | valdivia
# Processing Record 37 of Set 1 | fare
# Processing Record 38 of Set 1 | kismayo
# Processing Record 39 of Set 1 | great yarmouth
# Processing Record 40 of Set 1 | tommot
# Processing Record 41 of Set 1 | san juan
# Processing Record 42 of Set 1 | kulhudhuffushi
# Processing Record 43 of Set 1 | burnie
# Processing Record 44 of Set 1 | dingle
# Processing Record 45 of Set 1 | tazovskiy
# Processing Record 46 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 1 | constitucion
# Processing Record 50 of Set 1 | pyaozerskiy
# Processing Record 1 of Set 2 | vostok
# Processing Record 2 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | zhigansk
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | la ronge
# Processing Record 8 of Set 2 | guerrero negro
# Processing Record 9 of Set 2 | port macquarie
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | yar-sale
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | portland
# Processing Record 15 of Set 2 | broome
# Processing Record 16 of Set 2 | sur
# Processing Record 17 of Set 2 | halifax
# Processing Record 18 of Set 2 | teknaf
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | bam
# Processing Record 22 of Set 2 | ganzhou
# Processing Record 23 of Set 2 | kakamega
# Processing Record 24 of Set 2 | golyshmanovo
# Processing Record 25 of Set 2 | methoni
# Processing Record 26 of Set 2 | cooma
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | anadyr
# Processing Record 30 of Set 2 | talah
# City not found. Skipping...
# Processing Record 31 of Set 2 | angoram
# Processing Record 32 of Set 2 | caravelas
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | bilibino
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | olga
# Processing Record 39 of Set 2 | sfantu gheorghe
# Processing Record 40 of Set 2 | nayoro
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | summerland
# Processing Record 43 of Set 2 | okahandja
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | belaya gora
# Processing Record 46 of Set 2 | chara
# Processing Record 47 of Set 2 | rutland
# Processing Record 48 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 2 | caiaponia
# Processing Record 50 of Set 2 | bereda
# Processing Record 1 of Set 3 | garowe
# Processing Record 2 of Set 3 | jackson
# Processing Record 3 of Set 3 | ayan
# Processing Record 4 of Set 3 | kautokeino
# Processing Record 5 of Set 3 | luanda
# Processing Record 6 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | todos santos
# Processing Record 9 of Set 3 | srednekolymsk
# Processing Record 10 of Set 3 | vaini
# Processing Record 11 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | aswan
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | kisanga
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | batagay-alyta
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | misratah
# Processing Record 22 of Set 3 | nova olinda do norte
# Processing Record 23 of Set 3 | hammerfest
# Processing Record 24 of Set 3 | gemena
# Processing Record 25 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | santa isabel do rio negro
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | tigil
# Processing Record 30 of Set 3 | iqaluit
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | grindavik
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | natal
# Processing Record 38 of Set 3 | hambantota
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | pangai
# Processing Record 42 of Set 3 | mount pleasant
# Processing Record 43 of Set 3 | vila franca do campo
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | mahajanga
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | takab
# Processing Record 48 of Set 3 | aviles
# Processing Record 49 of Set 3 | port augusta
# Processing Record 50 of Set 3 | sao joao da barra
# Processing Record 1 of Set 4 | puerto leguizamo
# Processing Record 2 of Set 4 | farah
# Processing Record 3 of Set 4 | buala
# Processing Record 4 of Set 4 | ozark
# Processing Record 5 of Set 4 | jiuquan
# Processing Record 6 of Set 4 | sorong
# Processing Record 7 of Set 4 | karaton
# Processing Record 8 of Set 4 | san patricio
# Processing Record 9 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | ouargaye
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | sari
# Processing Record 15 of Set 4 | diamantino
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | amalapuram
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | rolla
# Processing Record 21 of Set 4 | innisfail
# Processing Record 22 of Set 4 | gigmoto
# Processing Record 23 of Set 4 | horta
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | andenes
# Processing Record 26 of Set 4 | beringovskiy
# Processing Record 27 of Set 4 | riyadh
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | mount isa
# Processing Record 30 of Set 4 | mkushi
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 4 | bom jardim
# Processing Record 34 of Set 4 | visby
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | nuuk
# Processing Record 37 of Set 4 | galesong
# Processing Record 38 of Set 4 | muros
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | manado
# Processing Record 41 of Set 4 | yerbogachen
# Processing Record 42 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 4 | kemerovo
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | orlik
# Processing Record 46 of Set 4 | ahipara
# Processing Record 47 of Set 4 | dauphin
# Processing Record 48 of Set 4 | bosaso
# Processing Record 49 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 4 | bandarbeyla
# Processing Record 1 of Set 5 | ongandjera
# Processing Record 2 of Set 5 | rocha
# Processing Record 3 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 5 | rostovka
# Processing Record 5 of Set 5 | olafsvik
# Processing Record 6 of Set 5 | peniche
# Processing Record 7 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 5 | faya
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | trelew
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | kulachi
# Processing Record 13 of Set 5 | neryungri
# Processing Record 14 of Set 5 | najran
# Processing Record 15 of Set 5 | jamestown
# Processing Record 16 of Set 5 | vyshkov
# Processing Record 17 of Set 5 | aklavik
# Processing Record 18 of Set 5 | gwadar
# Processing Record 19 of Set 5 | kosh-agach
# Processing Record 20 of Set 5 | vanino
# Processing Record 21 of Set 5 | barcelona
# Processing Record 22 of Set 5 | atar
# Processing Record 23 of Set 5 | nanortalik
# Processing Record 24 of Set 5 | rio gallegos
# Processing Record 25 of Set 5 | addanki
# Processing Record 26 of Set 5 | thunder bay
# Processing Record 27 of Set 5 | ilulissat
# Processing Record 28 of Set 5 | forbes
# Processing Record 29 of Set 5 | vung tau
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | kungurtug
# Processing Record 32 of Set 5 | bumbuna
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | abha
# Processing Record 35 of Set 5 | kondinskoye
# Processing Record 36 of Set 5 | havelock
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | clyde river
# Processing Record 39 of Set 5 | obo
# Processing Record 40 of Set 5 | khatanga
# Processing Record 41 of Set 5 | praia
# Processing Record 42 of Set 5 | kodinsk
# Processing Record 43 of Set 5 | martapura
# Processing Record 44 of Set 5 | ouadda
# Processing Record 45 of Set 5 | mogadishu
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | bundaberg
# Processing Record 48 of Set 5 | san vito dei normanni
# Processing Record 49 of Set 5 | nishihara
# Processing Record 50 of Set 5 | white rock
# Processing Record 1 of Set 6 | lorena
# Processing Record 2 of Set 6 | mporokoso
# Processing Record 3 of Set 6 | gorontalo
# Processing Record 4 of Set 6 | warora
# Processing Record 5 of Set 6 | sioux lookout
# Processing Record 6 of Set 6 | kalevala
# Processing Record 7 of Set 6 | baoying
# Processing Record 8 of Set 6 | ambovombe
# Processing Record 9 of Set 6 | kavieng
# Processing Record 10 of Set 6 | tucumcari
# Processing Record 11 of Set 6 | cap malheureux
# Processing Record 12 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 6 | taoudenni
# Processing Record 14 of Set 6 | killarney
# Processing Record 15 of Set 6 | ostrovnoy
# Processing Record 16 of Set 6 | arkhangelsk
# Processing Record 17 of Set 6 | talnakh
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | kamenka
# Processing Record 21 of Set 6 | kapoeta
# Processing Record 22 of Set 6 | vallenar
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 6 | sao miguel do araguaia
# Processing Record 26 of Set 6 | verkhnevilyuysk
# Processing Record 27 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 6 | valparaiso
# Processing Record 29 of Set 6 | potgietersrus
# City not found. Skipping...
# Processing Record 30 of Set 6 | yarada
# Processing Record 31 of Set 6 | siedlce
# Processing Record 32 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 6 | kokopo
# Processing Record 34 of Set 6 | manaure
# Processing Record 35 of Set 6 | kanjiza
# Processing Record 36 of Set 6 | jutai
# Processing Record 37 of Set 6 | pevek
# Processing Record 38 of Set 6 | yumen
# Processing Record 39 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 6 | saint-joseph
# Processing Record 41 of Set 6 | biak
# Processing Record 42 of Set 6 | marawi
# Processing Record 43 of Set 6 | vestmanna
# Processing Record 44 of Set 6 | norman wells
# Processing Record 45 of Set 6 | kupino
# Processing Record 46 of Set 6 | ndioum
# Processing Record 47 of Set 6 | lavrentiya
# Processing Record 48 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 6 | stilfontein
# Processing Record 50 of Set 6 | mar del plata
# Processing Record 1 of Set 7 | oranjestad
# Processing Record 2 of Set 7 | port hawkesbury
# Processing Record 3 of Set 7 | honningsvag
# Processing Record 4 of Set 7 | kurilsk
# Processing Record 5 of Set 7 | mixtequilla
# City not found. Skipping...
# Processing Record 6 of Set 7 | lujan
# Processing Record 7 of Set 7 | doha
# Processing Record 8 of Set 7 | ponta do sol
# Processing Record 9 of Set 7 | pringsewu
# Processing Record 10 of Set 7 | vila
# Processing Record 11 of Set 7 | necochea
# Processing Record 12 of Set 7 | egvekinot
# Processing Record 13 of Set 7 | souillac
# Processing Record 14 of Set 7 | samarai
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | nemuro
# Processing Record 17 of Set 7 | juneau
# Processing Record 18 of Set 7 | vestmannaeyjar
# Processing Record 19 of Set 7 | oktyabrskoye
# Processing Record 20 of Set 7 | narsaq
# Processing Record 21 of Set 7 | carmona
# Processing Record 22 of Set 7 | kamina
# Processing Record 23 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 24 of Set 7 | bayanday
# Processing Record 25 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 7 | havoysund
# Processing Record 27 of Set 7 | victoria
# Processing Record 28 of Set 7 | cedar city
# Processing Record 29 of Set 7 | biltine
# Processing Record 30 of Set 7 | tuatapere
# Processing Record 31 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 7 | palm valley
# Processing Record 33 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 7 | vila velha
# Processing Record 35 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 7 | sunbury
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | uddevalla
# Processing Record 39 of Set 7 | ulverstone
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | murray bridge
# Processing Record 42 of Set 7 | san quintin
# Processing Record 43 of Set 7 | trincomalee
# Processing Record 44 of Set 7 | maldonado
# Processing Record 45 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 7 | los llanos de aridane
# Processing Record 47 of Set 7 | burica
# City not found. Skipping...
# Processing Record 48 of Set 7 | vao
# Processing Record 49 of Set 7 | la paz
# Processing Record 50 of Set 7 | cabo san lucas
# Processing Record 1 of Set 8 | buin
# Processing Record 2 of Set 8 | pindiga
# Processing Record 3 of Set 8 | usogorsk
# Processing Record 4 of Set 8 | muravlenko
# Processing Record 5 of Set 8 | shujalpur
# Processing Record 6 of Set 8 | kloulklubed
# Processing Record 7 of Set 8 | alappuzha
# Processing Record 8 of Set 8 | galveston
# Processing Record 9 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 8 | sao joao da ponte
# Processing Record 11 of Set 8 | carnarvon
# Processing Record 12 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 8 | edd
# Processing Record 14 of Set 8 | sidi ali
# Processing Record 15 of Set 8 | vreed en hoop
# City not found. Skipping...
# Processing Record 16 of Set 8 | thetford mines
# Processing Record 17 of Set 8 | dunedin
# Processing Record 18 of Set 8 | sergeyevka
# Processing Record 19 of Set 8 | cayenne
# Processing Record 20 of Set 8 | chitral
# Processing Record 21 of Set 8 | vardo
# Processing Record 22 of Set 8 | nioro
# Processing Record 23 of Set 8 | kenai
# Processing Record 24 of Set 8 | kutum
# Processing Record 25 of Set 8 | the valley
# Processing Record 26 of Set 8 | salinopolis
# Processing Record 27 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 8 | san cristobal
# Processing Record 29 of Set 8 | skovorodino
# Processing Record 30 of Set 8 | chesma
# Processing Record 31 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 8 | georgiyevka
# Processing Record 33 of Set 8 | pacific grove
# Processing Record 34 of Set 8 | prince albert
# Processing Record 35 of Set 8 | bengkulu
# Processing Record 36 of Set 8 | mnogovershinnyy
# Processing Record 37 of Set 8 | pekan
# Processing Record 38 of Set 8 | port blair
# Processing Record 39 of Set 8 | harper
# Processing Record 40 of Set 8 | simplicio mendes
# Processing Record 41 of Set 8 | ponta delgada
# Processing Record 42 of Set 8 | barra dos coqueiros
# Processing Record 43 of Set 8 | nouadhibou
# Processing Record 44 of Set 8 | tsogni
# Processing Record 45 of Set 8 | barcelos
# Processing Record 46 of Set 8 | morondava
# Processing Record 47 of Set 8 | caucaia
# Processing Record 48 of Set 8 | komsomolskiy
# Processing Record 49 of Set 8 | abonnema
# Processing Record 50 of Set 8 | atambua
# Processing Record 1 of Set 9 | provideniya
# Processing Record 2 of Set 9 | suntar
# Processing Record 3 of Set 9 | altagracia de orituco
# Processing Record 4 of Set 9 | christchurch
# Processing Record 5 of Set 9 | rio grande
# Processing Record 6 of Set 9 | kargasok
# Processing Record 7 of Set 9 | douglas
# Processing Record 8 of Set 9 | ust-nera
# Processing Record 9 of Set 9 | hami
# Processing Record 10 of Set 9 | aykhal
# Processing Record 11 of Set 9 | mersin
# Processing Record 12 of Set 9 | kollam
# Processing Record 13 of Set 9 | montanha
# Processing Record 14 of Set 9 | eureka
# Processing Record 15 of Set 9 | alghero
# Processing Record 16 of Set 9 | callaguip
# Processing Record 17 of Set 9 | hvide sande
# Processing Record 18 of Set 9 | aljezur
# Processing Record 19 of Set 9 | mehamn
# Processing Record 20 of Set 9 | xifeng
# Processing Record 21 of Set 9 | salaga
# Processing Record 22 of Set 9 | fairbanks
# Processing Record 23 of Set 9 | quatre cocos
# Processing Record 24 of Set 9 | nagato
# Processing Record 25 of Set 9 | bani
# Processing Record 26 of Set 9 | hobyo
# Processing Record 27 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 9 | balkanabat
# Processing Record 29 of Set 9 | saint-gabriel
# Processing Record 30 of Set 9 | geraldton
# Processing Record 31 of Set 9 | aitape
# Processing Record 32 of Set 9 | bardiyah
# Processing Record 33 of Set 9 | deputatskiy
# Processing Record 34 of Set 9 | marigot
# Processing Record 35 of Set 9 | tulagi
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | palmer
# Processing Record 38 of Set 9 | mildura
# Processing Record 39 of Set 9 | hermagor
# Processing Record 40 of Set 9 | atascadero
# Processing Record 41 of Set 9 | canon city
# Processing Record 42 of Set 9 | owando
# Processing Record 43 of Set 9 | soyo
# Processing Record 44 of Set 9 | batagay
# Processing Record 45 of Set 9 | lagoa
# Processing Record 46 of Set 9 | shenjiamen
# Processing Record 47 of Set 9 | yamada
# Processing Record 48 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 9 | la libertad
# Processing Record 50 of Set 9 | port-gentil
# Processing Record 1 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 10 | de aar
# Processing Record 3 of Set 10 | crotone
# Processing Record 4 of Set 10 | viedma
# Processing Record 5 of Set 10 | saint-louis
# Processing Record 6 of Set 10 | tautira
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | yining
# Processing Record 9 of Set 10 | touros
# Processing Record 10 of Set 10 | padang
# Processing Record 11 of Set 10 | taltal
# Processing Record 12 of Set 10 | margate
# Processing Record 13 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 10 | superior
# Processing Record 15 of Set 10 | kannangad
# Processing Record 16 of Set 10 | belvidere
# Processing Record 17 of Set 10 | gizo
# Processing Record 18 of Set 10 | nizwa
# Processing Record 19 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 10 | chizhou
# Processing Record 21 of Set 10 | chimoio
# Processing Record 22 of Set 10 | helong
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | kupang
# Processing Record 25 of Set 10 | progreso
# Processing Record 26 of Set 10 | mirnyy
# Processing Record 27 of Set 10 | mount gambier
# Processing Record 28 of Set 10 | dudinka
# Processing Record 29 of Set 10 | yian
# City not found. Skipping...
# Processing Record 30 of Set 10 | henties bay
# Processing Record 31 of Set 10 | jinka
# Processing Record 32 of Set 10 | saint-augustin
# Processing Record 33 of Set 10 | izhma
# Processing Record 34 of Set 10 | podosinovets
# Processing Record 35 of Set 10 | wankaner
# Processing Record 36 of Set 10 | koungou
# Processing Record 37 of Set 10 | pravdinskiy
# Processing Record 38 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 10 | tecoanapa
# Processing Record 40 of Set 10 | labuhan
# Processing Record 41 of Set 10 | puerto cabezas
# Processing Record 42 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 43 of Set 10 | thomaston
# Processing Record 44 of Set 10 | port hardy
# Processing Record 45 of Set 10 | wau
# Processing Record 46 of Set 10 | goure
# Processing Record 47 of Set 10 | galle
# Processing Record 48 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 10 | raga
# Processing Record 50 of Set 10 | tabou
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | flin flon
# Processing Record 3 of Set 11 | laguna
# Processing Record 4 of Set 11 | konya
# Processing Record 5 of Set 11 | arlit
# Processing Record 6 of Set 11 | beruni
# City not found. Skipping...
# Processing Record 7 of Set 11 | kidal
# Processing Record 8 of Set 11 | paka
# Processing Record 9 of Set 11 | starotimoshkino
# Processing Record 10 of Set 11 | fujin
# Processing Record 11 of Set 11 | zile
# Processing Record 12 of Set 11 | buraydah
# Processing Record 13 of Set 11 | ahuimanu
# Processing Record 14 of Set 11 | chicama
# Processing Record 15 of Set 11 | dinguiraye
# Processing Record 16 of Set 11 | cantaura
# Processing Record 17 of Set 11 | erzin
# Processing Record 18 of Set 11 | shumskiy
# Processing Record 19 of Set 11 | harlingen
# Processing Record 20 of Set 11 | troina
# Processing Record 21 of Set 11 | liverpool
# Processing Record 22 of Set 11 | wa
# City not found. Skipping...
# Processing Record 23 of Set 11 | coronel martinez
# Processing Record 24 of Set 11 | comodoro rivadavia
# Processing Record 25 of Set 11 | ngunguru
# Processing Record 26 of Set 11 | saint-georges
# Processing Record 27 of Set 11 | esparta
# Processing Record 28 of Set 11 | atexcatzingo
# Processing Record 29 of Set 11 | haverfordwest
# Processing Record 30 of Set 11 | arraial do cabo
# Processing Record 31 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 11 | kemin
# Processing Record 33 of Set 11 | cap-aux-meules
# Processing Record 34 of Set 11 | ust-tsilma
# Processing Record 35 of Set 11 | peace river
# Processing Record 36 of Set 11 | thinadhoo
# Processing Record 37 of Set 11 | kaeo
# Processing Record 38 of Set 11 | williston
# Processing Record 39 of Set 11 | palaikastron
# Processing Record 40 of Set 11 | marystown
# Processing Record 41 of Set 11 | emba
# Processing Record 42 of Set 11 | peekskill
# Processing Record 43 of Set 11 | sabla
# Processing Record 44 of Set 11 | maryville
# Processing Record 45 of Set 11 | letpadan
# Processing Record 46 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 11 | kysyl-syr
# Processing Record 48 of Set 11 | morden
# Processing Record 49 of Set 11 | tera
# Processing Record 50 of Set 11 | port lincoln
# Processing Record 1 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 12 | artyom
# Processing Record 3 of Set 12 | sao joao evangelista
# Processing Record 4 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 12 | antofagasta
# Processing Record 6 of Set 12 | bukama
# Processing Record 7 of Set 12 | thessalon
# Processing Record 8 of Set 12 | husavik
# Processing Record 9 of Set 12 | college
# Processing Record 10 of Set 12 | sevierville
# Processing Record 11 of Set 12 | amarpur
# Processing Record 12 of Set 12 | malinovoye ozero
# Processing Record 13 of Set 12 | kiama
# Processing Record 14 of Set 12 | sibu
# Processing Record 15 of Set 12 | yazman
# Processing Record 16 of Set 12 | kyabe
# Processing Record 17 of Set 12 | orocue
# Processing Record 18 of Set 12 | vanimo
# Processing Record 19 of Set 12 | hailar
# Processing Record 20 of Set 12 | kalemie
# Processing Record 21 of Set 12 | zarand
# Processing Record 22 of Set 12 | grand gaube
# Processing Record 23 of Set 12 | okhotsk
# Processing Record 24 of Set 12 | florianopolis
# Processing Record 25 of Set 12 | sakaiminato
# Processing Record 26 of Set 12 | gondanglegi
# Processing Record 27 of Set 12 | prince rupert
# Processing Record 28 of Set 12 | daru
# Processing Record 29 of Set 12 | hay river
# Processing Record 30 of Set 12 | machala
# Processing Record 31 of Set 12 | yokadouma
# Processing Record 32 of Set 12 | turayf
# Processing Record 33 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 34 of Set 12 | mtwara
# Processing Record 35 of Set 12 | gat
# Processing Record 36 of Set 12 | novoorsk
# Processing Record 37 of Set 12 | tucuman
# Processing Record 38 of Set 12 | klaksvik
# Processing Record 39 of Set 12 | poronaysk
# Processing Record 40 of Set 12 | metro
# Processing Record 41 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 42 of Set 12 | cologno monzese
# Processing Record 43 of Set 12 | turukhansk
# Processing Record 44 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 45 of Set 12 | bignona
# Processing Record 46 of Set 12 | stephenville
# Processing Record 47 of Set 12 | oyama
# Processing Record 48 of Set 12 | novoye leushino
# Processing Record 49 of Set 12 | kropotkin
# Processing Record 50 of Set 12 | plettenberg bay
# Processing Record 1 of Set 13 | seoul
# Processing Record 2 of Set 13 | manavalakurichi
# Processing Record 3 of Set 13 | dhidhdhoo
# Processing Record 4 of Set 13 | rosetta
# Processing Record 5 of Set 13 | maragogi
# Processing Record 6 of Set 13 | coihaique
# Processing Record 7 of Set 13 | kudahuvadhoo
# Processing Record 8 of Set 13 | bosobolo
# Processing Record 9 of Set 13 | willowmore
# Processing Record 10 of Set 13 | winnemucca
# Processing Record 11 of Set 13 | joshimath
# Processing Record 12 of Set 13 | jamsa
# Processing Record 13 of Set 13 | copacabana
# Processing Record 14 of Set 13 | kongolo
# Processing Record 15 of Set 13 | san matias
# Processing Record 16 of Set 13 | polson
# Processing Record 17 of Set 13 | kanniyakumari
# Processing Record 18 of Set 13 | ulladulla
# Processing Record 19 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 13 | mananara
# Processing Record 21 of Set 13 | san severo
# Processing Record 22 of Set 13 | babu
# Processing Record 23 of Set 13 | mitsamiouli
# Processing Record 24 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 13 | high level
# Processing Record 26 of Set 13 | umba
# Processing Record 27 of Set 13 | erenhot
# Processing Record 28 of Set 13 | cherskiy
# Processing Record 29 of Set 13 | richards bay
# Processing Record 30 of Set 13 | moulins
# Processing Record 31 of Set 13 | malakal
# Processing Record 32 of Set 13 | tabuk
# Processing Record 33 of Set 13 | roald
# Processing Record 34 of Set 13 | paamiut
# Processing Record 35 of Set 13 | paralimni
# Processing Record 36 of Set 13 | tevriz
# Processing Record 37 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 13 | saint-francois
# Processing Record 39 of Set 13 | bathsheba
# Processing Record 40 of Set 13 | yuryev-polskiy
# Processing Record 41 of Set 13 | moranbah
# Processing Record 42 of Set 13 | karratha
# Processing Record 43 of Set 13 | kenmare
# Processing Record 44 of Set 13 | port moresby
# Processing Record 45 of Set 13 | isangel
# Processing Record 46 of Set 13 | baft
# Processing Record 47 of Set 13 | sundargarh
# Processing Record 48 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 13 | gimli
# Processing Record 50 of Set 13 | bodden town
# Processing Record 1 of Set 14 | kenora
# Processing Record 2 of Set 14 | aberdeen
# Processing Record 3 of Set 14 | sistranda
# Processing Record 4 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 14 | inirida
# Processing Record 6 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 14 | vaitape
# Processing Record 8 of Set 14 | bastrop
# Processing Record 9 of Set 14 | tilichiki
# Processing Record 10 of Set 14 | rotterdam
# Processing Record 11 of Set 14 | muroto
# Processing Record 12 of Set 14 | kaspiyskiy
# Processing Record 13 of Set 14 | ixtapa
# Processing Record 14 of Set 14 | baneh
# Processing Record 15 of Set 14 | karpinsk
# Processing Record 16 of Set 14 | pavlivka
# Processing Record 17 of Set 14 | havre-saint-pierre
# Processing Record 18 of Set 14 | bonavista
# Processing Record 19 of Set 14 | shubarkuduk
# Processing Record 20 of Set 14 | loreto
# Processing Record 21 of Set 14 | esperance
# Processing Record 22 of Set 14 | ust-kuyga
# Processing Record 23 of Set 14 | nabire
# Processing Record 24 of Set 14 | maloy
# Processing Record 25 of Set 14 | naron
# Processing Record 26 of Set 14 | kasaragod
# Processing Record 27 of Set 14 | pampa
# Processing Record 28 of Set 14 | sao jose da coroa grande
# Processing Record 29 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 14 | acajutla
# Processing Record 31 of Set 14 | beloha
# Processing Record 32 of Set 14 | hastings
# Processing Record 33 of Set 14 | honiara
# Processing Record 34 of Set 14 | santa maria
# Processing Record 35 of Set 14 | poya
# Processing Record 36 of Set 14 | meadow lake
# Processing Record 37 of Set 14 | sampit
# Processing Record 38 of Set 14 | soe
# Processing Record 39 of Set 14 | noumea
# Processing Record 40 of Set 14 | luis correia
# Processing Record 41 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 14 | kahului
# Processing Record 43 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 14 | rivadavia
# Processing Record 45 of Set 14 | kuzedeyevo
# Processing Record 46 of Set 14 | kirillov
# Processing Record 47 of Set 14 | requena
# Processing Record 48 of Set 14 | morant bay
# Processing Record 49 of Set 14 | lata
# Processing Record 50 of Set 14 | goya
# Processing Record 1 of Set 15 | alibag
# Processing Record 2 of Set 15 | poum
# Processing Record 3 of Set 15 | zima
# Processing Record 4 of Set 15 | santa rosa
# Processing Record 5 of Set 15 | senneterre
# Processing Record 6 of Set 15 | borogontsy
# Processing Record 7 of Set 15 | gold coast
# Processing Record 8 of Set 15 | barreirinha
# Processing Record 9 of Set 15 | pasighat
# Processing Record 10 of Set 15 | coahuayana
# Processing Record 11 of Set 15 | franklin park
# Processing Record 12 of Set 15 | yulara
# Processing Record 13 of Set 15 | mangrol
# Processing Record 14 of Set 15 | tadine
# Processing Record 15 of Set 15 | ladario
# Processing Record 16 of Set 15 | glenwood springs
# Processing Record 17 of Set 15 | kharp
# Processing Record 18 of Set 15 | kpandu
# Processing Record 19 of Set 15 | bocana de paiwas
# Processing Record 20 of Set 15 | brae
# Processing Record 21 of Set 15 | yatou
# Processing Record 22 of Set 15 | labis
# Processing Record 23 of Set 15 | freeport
# Processing Record 24 of Set 15 | hovd
# Processing Record 25 of Set 15 | xianyang
# Processing Record 26 of Set 15 | yefira
# City not found. Skipping...
# Processing Record 27 of Set 15 | nyurba
# Processing Record 28 of Set 15 | harrisburg
# Processing Record 29 of Set 15 | tomatlan
# Processing Record 30 of Set 15 | san francisco
# Processing Record 31 of Set 15 | takapau
# Processing Record 32 of Set 15 | namibe
# Processing Record 33 of Set 15 | lafiagi
# Processing Record 34 of Set 15 | puerto carreno
# Processing Record 35 of Set 15 | salalah
# Processing Record 36 of Set 15 | cururupu
# Processing Record 37 of Set 15 | itoman
# Processing Record 38 of Set 15 | bluefields
# Processing Record 39 of Set 15 | vysokaya gora
# Processing Record 40 of Set 15 | chapada dos guimaraes
# Processing Record 41 of Set 15 | irbil
# Processing Record 42 of Set 15 | urumqi
# Processing Record 43 of Set 15 | houma
# Processing Record 44 of Set 15 | nicoya
# Processing Record 45 of Set 15 | acari
# Processing Record 46 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 47 of Set 15 | hokitika
# Processing Record 48 of Set 15 | yebaishou
# Processing Record 49 of Set 15 | amapa
# Processing Record 50 of Set 15 | kuala pilah
# Processing Record 1 of Set 16 | abu dhabi
# Processing Record 2 of Set 16 | omsukchan
# Processing Record 3 of Set 16 | niquelandia
# Processing Record 4 of Set 16 | marathon
# Processing Record 5 of Set 16 | nauta
# Processing Record 6 of Set 16 | mackenzie
# Processing Record 7 of Set 16 | tessalit
# Processing Record 8 of Set 16 | anshun
# Processing Record 9 of Set 16 | iwanai
# Processing Record 10 of Set 16 | denpasar
# Processing Record 11 of Set 16 | borovoy
# Processing Record 12 of Set 16 | taywarah
# Processing Record 13 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 16 | jinxiang
# Processing Record 15 of Set 16 | liku
# Processing Record 16 of Set 16 | aktas
# Processing Record 17 of Set 16 | alofi
# Processing Record 18 of Set 16 | santiago del estero
# Processing Record 19 of Set 16 | mangochi
# Processing Record 20 of Set 16 | pangnirtung
# Processing Record 21 of Set 16 | baykit
# Processing Record 22 of Set 16 | santa fe
# Processing Record 23 of Set 16 | gap
# Processing Record 24 of Set 16 | jibuti
# Processing Record 25 of Set 16 | rudbar
# Processing Record 26 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 16 | punta alta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Bredasdorp      ZA -34.5322   20.0403     66.27        60          39
# 1   Nikolskoye      RU  59.7035   30.7861     37.87        97         100
# 2        Avera      US  33.1940  -82.5271     33.46        34           0
# 3       Avarua      CK -21.2078 -159.7750     73.45        73         100
# 4  New Norfolk      AU -42.7826  147.0587     70.75        63          98
# 5        Homer      US  59.6425 -151.5483     17.04        79         100
# 6         Hilo      US  19.7297 -155.0900     82.27        94         100
# 7      Mataura      NZ -46.1927  168.8643     57.11        63         100
# 8         Asau      RO  46.4333   26.4000     39.76        88          97
# 9       Castro      BR -24.7911  -50.0119     59.81        92         100
#
#    Wind Speed Current Description
# 0       14.45    scattered clouds
# 1       13.85          light snow
# 2        2.84           clear sky
# 3        5.75     overcast clouds
# 4        2.53     overcast clouds
# 5        7.43     overcast clouds
# 6        1.01     overcast clouds
# 7        4.88     overcast clouds
# 8        3.06     overcast clouds
# 9        9.10     overcast clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
